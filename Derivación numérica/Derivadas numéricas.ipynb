# %%
using Plots

# %%
function derivada_derecha(f,h,x₀)
    (f(x₀+h)-f(x₀)) / h
end
# Out:
# derivada_derecha (generic function with 1 method)

# %%
f(x) = 3*x^3 - 2
# Out:
# f (generic function with 1 method)

# %%
ies = Float64[]
for i = 1:15
    push!(ies,10.0^(-i))
end

ies
# Out:
# 15-element Vector{Float64}:
#  0.1
#  0.010000000000000002
#  0.001
#  0.0001
#  1.0e-5
#  1.0e-6
#  1.0000000000000001e-7
#  1.0e-8
#  1.0e-9
#  1.0e-10
#  1.0e-11
#  1.0000000000000002e-12
#  1.0e-13
#  1.0e-14
#  1.0e-15

# %%
plot(ies,derivada_derecha.(f,ies,1), yscale = :log, xscale = :log)
# Out:
# ┌ Warning: scale log is unsupported with Plots.GRBackend().
# │ Choose from: [:identity, :ln, :log10, :log2]
# └ @ Plots ~/.julia/packages/Plots/3BCH5/src/args.jl:1584
# ┌ Warning: scale log is unsupported with Plots.GRBackend().
# │ Choose from: [:identity, :ln, :log10, :log2]
# └ @ Plots ~/.julia/packages/Plots/3BCH5/src/args.jl:1584

# %%
function derivada_simetrica(f,h,x₀)
    (f(x₀+h)-f(x₀-h)) / (2*h)
end
# Out:
# derivada_simetrica (generic function with 1 method)

# %%
function derivada_imaginaria(f,h,x₀)
    imag((f(x₀+h*im))) / h
    
end
# Out:
# derivada_imaginaria (generic function with 1 method)

# %%
ies = Float64[]
for i = 1:120
    push!(ies,10.0^(-0.125 * i))
end

println()

plot(title = "Precisión de diferentes derivadas",
    yscale = :log10, 
    xscale = :log10, 
    xlims = (1e-16,1), 
    ylims = (1e-16,1),
    legend = :left, 
    xlabel= "h", 
    ylabel = "Error")

plot!(ies,abs.(derivada_simetrica.(f,ies,1).-9), label = "Simétrica",)
plot!(ies,abs.(derivada_derecha.(f,ies,1).-9), label = "Derecha")
plot!(ies,abs.(derivada_imaginaria.(f,ies,1).-9), label = "Compleja")
